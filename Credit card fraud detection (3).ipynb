# %%
## Descriptiopn of the project- Credit card fraud detection
#prepared by Ashwini Vishwanathan and Rohini Vishwanathan
#Main Motive of the project is to identitfy the fraud transcation

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
## import data from C drive 
data = pd.read_csv("creditcard.csv")

# %%
data.head(200)
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 0      0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1      0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2      1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3      1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4      2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ..     ...       ...       ...       ...       ...       ...       ...
# 195  128.0  1.239495 -0.182609  0.155058 -0.928892 -0.746227 -1.235608
# 196  130.0 -0.485238  0.658497  1.949967  1.249695  0.426410  0.231513
# 197  130.0  1.353283 -0.694900  0.970826 -0.426559 -1.417263 -0.505710
# 198  131.0 -1.007391  1.261943  1.207203  1.307575  0.153211  0.062291
# 199  132.0 -0.394816  1.054418  1.206361 -0.289232  0.610284  0.081529
#
#            V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
## Get the Fraud and the normal dataset
fraud = data.loc[data['Class'] == 1] 
normal = data.loc[data['Class'] == 0]

# %%
fraud
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
fraud.count()
# Out:
# Time      492
# V1        492
# V2        492
# V3        492
# V4        492
# V5        492
# V6        492
# V7        492
# V8        492
# V9        492
# V10       492
# V11       492
# V12       492
# V13       492
# V14       492
# V15       492
# V16       492
# V17       492
# V18       492
# V19       492
# V20       492
# V21       492
# V22       492
# V23       492
# V24       492
# V25       492
# V26       492
# V27       492
# V28       492
# Amount    492
# Class     492
# dtype: int64

# %%
fraud.sum()
# Out:
# Time      3.972743e+07
# V1       -2.347799e+03
# V2        1.782899e+03
# V3       -3.460374e+03
# V4        2.234678e+03
# V5       -1.550403e+03
# V6       -6.876865e+02
# V7       -2.739816e+03
# V8        2.807529e+02
# V9       -1.269912e+03
# V10      -2.793026e+03
# V11       1.869685e+03
# V12      -3.079621e+03
# V13      -5.379224e+01
# V14      -3.430088e+03
# V15      -4.572094e+01
# V16      -2.036853e+03
# V17      -3.279592e+03
# V18      -1.105184e+03
# V19       3.348844e+02
# V20       1.831811e+02
# V21       3.510855e+02
# V22       6.912050e+00
# V23      -1.983152e+01
# V24      -5.172411e+01
# V25       2.039285e+01
# V26       2.541088e+01
# V27       8.392280e+01
# V28       3.722831e+01
# Amount    6.012797e+04
# Class     4.920000e+02
# dtype: float64

# %%
len(fraud)
# Out:
# 492

# %%
len(normal)
# Out:
# 284315

# %%
sns.relplot(x= 'Amount', y="Class", data=data )

# %%
## We will check do fradulent transcations occur more often during certain time frame
sns.relplot(x= 'Amount', y="Time",hue="Class", data=data ) #hue is used to group multiple data variable to show the dependency of the passed data values.

# %%
import scipy
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from pylab import rcParams

# %%
X = data.iloc[:,:-1]
Y = data['Class']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size= 0.45)

# %%
Clf = linear_model.LogisticRegression(C=1.56)

# %%
Clf.fit(X_train, Y_train)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=1.56)

# %%
Y_pred = np.array(Clf.predict(X_test))
Y = np.array(Y_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
print(confusion_matrix(Y_test, Y_pred))
# Out:
# [[127887     73]
#  [    63    141]]

# %%
print(accuracy_score(Y_test,Y_pred))
# Out:
# 0.9989388595861552

# %%
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    127960
#            1       0.66      0.69      0.67       204
#
#     accuracy                           1.00    128164
#    macro avg       0.83      0.85      0.84    128164
# weighted avg       1.00      1.00      1.00    128164

# %%
## We need to analyze more amount of information from the transcation data
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transcation ')
bins = 50
ax1.hist(fraud.Amount, bins = bins)
ax1.set_title('Fraud')
ax2.hist(normal.Amount, bins =bins)
ax2.set_title('Normal')
plt.xlabel('Amount ($)')
plt.ylabel('Number of Transcations')
plt.xlim((0,10000))
plt.yscale('log')
plt.show();

# %%
## Correlation
import seaborn as sns
#get correlations of each features in dataset
corrmat = data.corr()
top_corr_features =corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True)
